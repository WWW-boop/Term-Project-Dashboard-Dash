# %%
from pycaret.regression import *
import pandas as pd

data = pd.read_csv('csv\pm25_new2.csv')
s = setup(data, target = 'PM25', session_id = 123)
# Out:
# <style type="text/css">
# #T_b153e_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b153e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b153e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b153e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b153e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b153e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b153e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b153e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b153e_row1_col1" class="data row1 col1" >PM25</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b153e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b153e_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b153e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_b153e_row3_col1" class="data row3 col1" >(2136, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b153e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_b153e_row4_col1" class="data row4 col1" >(2136, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b153e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_b153e_row5_col1" class="data row5 col1" >(1495, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b153e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_b153e_row6_col1" class="data row6 col1" >(641, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b153e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_b153e_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b153e_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_b153e_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b153e_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_b153e_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b153e_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_b153e_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b153e_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_b153e_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b153e_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_b153e_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b153e_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_b153e_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b153e_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_b153e_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b153e_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_b153e_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b153e_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_b153e_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b153e_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_b153e_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b153e_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_b153e_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b153e_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_b153e_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b153e_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_b153e_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b153e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b153e_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_b153e_row21_col1" class="data row21 col1" >e6df</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_00843 th {
#   text-align: left;
# }
# #T_00843_row0_col0, #T_00843_row0_col1, #T_00843_row0_col6, #T_00843_row1_col0, #T_00843_row1_col1, #T_00843_row1_col2, #T_00843_row1_col3, #T_00843_row1_col4, #T_00843_row1_col5, #T_00843_row1_col6, #T_00843_row2_col0, #T_00843_row2_col1, #T_00843_row2_col2, #T_00843_row2_col3, #T_00843_row2_col4, #T_00843_row2_col5, #T_00843_row2_col6, #T_00843_row3_col0, #T_00843_row3_col1, #T_00843_row3_col2, #T_00843_row3_col3, #T_00843_row3_col4, #T_00843_row3_col5, #T_00843_row3_col6, #T_00843_row4_col0, #T_00843_row4_col2, #T_00843_row4_col3, #T_00843_row4_col4, #T_00843_row4_col5, #T_00843_row5_col0, #T_00843_row5_col1, #T_00843_row5_col2, #T_00843_row5_col3, #T_00843_row5_col4, #T_00843_row5_col5, #T_00843_row5_col6, #T_00843_row6_col0, #T_00843_row6_col1, #T_00843_row6_col2, #T_00843_row6_col3, #T_00843_row6_col4, #T_00843_row6_col5, #T_00843_row6_col6, #T_00843_row7_col0, #T_00843_row7_col1, #T_00843_row7_col2, #T_00843_row7_col3, #T_00843_row7_col4, #T_00843_row7_col5, #T_00843_row7_col6, #T_00843_row8_col0, #T_00843_row8_col1, #T_00843_row8_col2, #T_00843_row8_col3, #T_00843_row8_col4, #T_00843_row8_col5, #T_00843_row8_col6, #T_00843_row9_col0, #T_00843_row9_col1, #T_00843_row9_col2, #T_00843_row9_col3, #T_00843_row9_col4, #T_00843_row9_col5, #T_00843_row9_col6, #T_00843_row10_col0, #T_00843_row10_col1, #T_00843_row10_col2, #T_00843_row10_col3, #T_00843_row10_col4, #T_00843_row10_col5, #T_00843_row10_col6, #T_00843_row11_col0, #T_00843_row11_col1, #T_00843_row11_col2, #T_00843_row11_col3, #T_00843_row11_col4, #T_00843_row11_col5, #T_00843_row11_col6, #T_00843_row12_col0, #T_00843_row12_col1, #T_00843_row12_col2, #T_00843_row12_col3, #T_00843_row12_col4, #T_00843_row12_col5, #T_00843_row12_col6, #T_00843_row13_col0, #T_00843_row13_col1, #T_00843_row13_col2, #T_00843_row13_col3, #T_00843_row13_col4, #T_00843_row13_col5, #T_00843_row13_col6, #T_00843_row14_col0, #T_00843_row14_col1, #T_00843_row14_col2, #T_00843_row14_col3, #T_00843_row14_col4, #T_00843_row14_col5, #T_00843_row14_col6, #T_00843_row15_col0, #T_00843_row15_col1, #T_00843_row15_col2, #T_00843_row15_col3, #T_00843_row15_col4, #T_00843_row15_col5, #T_00843_row15_col6, #T_00843_row16_col0, #T_00843_row16_col1, #T_00843_row16_col2, #T_00843_row16_col3, #T_00843_row16_col4, #T_00843_row16_col5, #T_00843_row16_col6, #T_00843_row17_col0, #T_00843_row17_col1, #T_00843_row17_col2, #T_00843_row17_col3, #T_00843_row17_col4, #T_00843_row17_col5, #T_00843_row17_col6 {
#   text-align: left;
# }
# #T_00843_row0_col2, #T_00843_row0_col3, #T_00843_row0_col4, #T_00843_row0_col5, #T_00843_row4_col1, #T_00843_row4_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_00843_row0_col7, #T_00843_row1_col7, #T_00843_row2_col7, #T_00843_row3_col7, #T_00843_row4_col7, #T_00843_row5_col7, #T_00843_row6_col7, #T_00843_row7_col7, #T_00843_row8_col7, #T_00843_row9_col7, #T_00843_row11_col7, #T_00843_row12_col7, #T_00843_row13_col7, #T_00843_row14_col7, #T_00843_row15_col7, #T_00843_row16_col7, #T_00843_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_00843_row10_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_00843">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00843_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_00843_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_00843_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_00843_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_00843_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_00843_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_00843_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_00843_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00843_level0_row0" class="row_heading level0 row0" >en</th>
#       <td id="T_00843_row0_col0" class="data row0 col0" >Elastic Net</td>
#       <td id="T_00843_row0_col1" class="data row0 col1" >3.8481</td>
#       <td id="T_00843_row0_col2" class="data row0 col2" >24.5746</td>
#       <td id="T_00843_row0_col3" class="data row0 col3" >4.9337</td>
#       <td id="T_00843_row0_col4" class="data row0 col4" >0.0518</td>
#       <td id="T_00843_row0_col5" class="data row0 col5" >0.2848</td>
#       <td id="T_00843_row0_col6" class="data row0 col6" >0.2629</td>
#       <td id="T_00843_row0_col7" class="data row0 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_00843_level0_row1" class="row_heading level0 row1" >omp</th>
#       <td id="T_00843_row1_col0" class="data row1 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_00843_row1_col1" class="data row1 col1" >3.9109</td>
#       <td id="T_00843_row1_col2" class="data row1 col2" >24.9100</td>
#       <td id="T_00843_row1_col3" class="data row1 col3" >4.9683</td>
#       <td id="T_00843_row1_col4" class="data row1 col4" >0.0380</td>
#       <td id="T_00843_row1_col5" class="data row1 col5" >0.2875</td>
#       <td id="T_00843_row1_col6" class="data row1 col6" >0.2675</td>
#       <td id="T_00843_row1_col7" class="data row1 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_00843_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_00843_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_00843_row2_col1" class="data row2 col1" >3.8884</td>
#       <td id="T_00843_row2_col2" class="data row2 col2" >25.2643</td>
#       <td id="T_00843_row2_col3" class="data row2 col3" >5.0015</td>
#       <td id="T_00843_row2_col4" class="data row2 col4" >0.0263</td>
#       <td id="T_00843_row2_col5" class="data row2 col5" >0.2880</td>
#       <td id="T_00843_row2_col6" class="data row2 col6" >0.2656</td>
#       <td id="T_00843_row2_col7" class="data row2 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_00843_level0_row3" class="row_heading level0 row3" >llar</th>
#       <td id="T_00843_row3_col0" class="data row3 col0" >Lasso Least Angle Regression</td>
#       <td id="T_00843_row3_col1" class="data row3 col1" >3.8884</td>
#       <td id="T_00843_row3_col2" class="data row3 col2" >25.2643</td>
#       <td id="T_00843_row3_col3" class="data row3 col3" >5.0015</td>
#       <td id="T_00843_row3_col4" class="data row3 col4" >0.0263</td>
#       <td id="T_00843_row3_col5" class="data row3 col5" >0.2880</td>
#       <td id="T_00843_row3_col6" class="data row3 col6" >0.2656</td>
#       <td id="T_00843_row3_col7" class="data row3 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_00843_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_00843_row4_col0" class="data row4 col0" >K Neighbors Regressor</td>
#       <td id="T_00843_row4_col1" class="data row4 col1" >3.8362</td>
#       <td id="T_00843_row4_col2" class="data row4 col2" >25.6623</td>
#       <td id="T_00843_row4_col3" class="data row4 col3" >5.0455</td>
#       <td id="T_00843_row4_col4" class="data row4 col4" >0.0055</td>
#       <td id="T_00843_row4_col5" class="data row4 col5" >0.2877</td>
#       <td id="T_00843_row4_col6" class="data row4 col6" >0.2530</td>
#       <td id="T_00843_row4_col7" class="data row4 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_00843_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_00843_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_00843_row5_col1" class="data row5 col1" >3.9402</td>
#       <td id="T_00843_row5_col2" class="data row5 col2" >26.0757</td>
#       <td id="T_00843_row5_col3" class="data row5 col3" >5.0813</td>
#       <td id="T_00843_row5_col4" class="data row5 col4" >-0.0050</td>
#       <td id="T_00843_row5_col5" class="data row5 col5" >0.2919</td>
#       <td id="T_00843_row5_col6" class="data row5 col6" >0.2688</td>
#       <td id="T_00843_row5_col7" class="data row5 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_00843_level0_row6" class="row

# %%
preds = predict_model(best, data=data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1243f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1243f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1243f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1243f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1243f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1243f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1243f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1243f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1243f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1243f_row0_col0" class="data row0 col0" >Elastic Net</td>
#       <td id="T_1243f_row0_col1" class="data row0 col1" >2.8173</td>
#       <td id="T_1243f_row0_col2" class="data row0 col2" >13.8231</td>
#       <td id="T_1243f_row0_col3" class="data row0 col3" >3.7179</td>
#       <td id="T_1243f_row0_col4" class="data row0 col4" >0.4676</td>
#       <td id="T_1243f_row0_col5" class="data row0 col5" >0.2202</td>
#       <td id="T_1243f_row0_col6" class="data row0 col6" >0.1936</td>
#     </tr>
#   </tbody>
# </table>

# %%
preds.to_csv('csv\predicted_pm25.csv', index=False)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
save_model(best, 'predict101')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['O3', 'WS', 'TEMP', 'RH', 'WD'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['DATETIMEDATA', 'stationID'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['stationID'],
#                                      transformer=OneHotEncoder(cols=['stationID'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('rest_encoding',
#                   TransformerWrapper(include=['DATETIMEDATA'],
#                                      transformer=TargetEncoder(cols=['DATETIMEDATA'],
#                                                                handle_missing='return_nan'))),
#                  ('trained_model', ElasticNet(random_state=123))]),
#  'predict101.pkl')
